# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea

from  sklearn.preprocessing import StandardScaler

# %%
df = pd.read_excel('/content/Predicted_data mlpa.xlsx')
df.head(5)
# Out:
#    s_id  name                                       profile_link  tier gender  \
# 0   1.0   NaN  https://www.linkedin.com/in/shubham-yadav-b862...     1      M
# 1   2.0   NaN  https://www.linkedin.com/in/pranav-patel-97780...     1      M
# 2   3.0   NaN          https://www.linkedin.com/in/kshitij-garg/     1      M
# 3   4.0   NaN   https://www.linkedin.com/in/akash-garg-5757a290/     1      M
# 4   5.0   NaN  https://www.linkedin.com/in/shubham-jadhav-493...     1      M
#
#   branch  cgpa  inter_gpa  ssc_gpa  internships  ...  \
# 0    CSE   NaN        NaN     10.0          2.0  ...
# 1    CSE   NaN        NaN     10.0          1.0  ...
# 2    CSE   NaN        NaN      NaN          1.0  ...
# 3    CSE  9.59        NaN     10.0          3.0  ...
# 4    CSE   NaN        NaN      9.8          3.0  ...
#
#    is_participated_extracurricular  no_of_programming_languages  dsa  \
# 0                              1.0                          4.0  1.0
# ...

# %%
df.columns
# Out:
# Index(['s_id', 'name', 'profile_link', 'tier', 'gender', 'branch', 'cgpa',
#        'inter_gpa', 'ssc_gpa', 'internships', 'no_of_projects',
#        'is_participate_hackathon', 'is_participated_extracurricular',
#        'no_of_programming_languages', 'dsa', 'mobile_dev', 'web_dev',
#        'Machine Learning', 'cloud', 'other_skills', 'is_placed',
#        'salary_as_fresher'],
#       dtype='object')

# %%
df.drop(columns=['s_id','name','profile_link','gender'],inplace=True)

# %%
df
# Out:
#      tier branch  cgpa  inter_gpa  ssc_gpa  internships  no_of_projects  \
# 0       1    CSE   NaN        NaN     10.0          2.0             5.0
# 1       1    CSE   NaN        NaN     10.0          1.0             4.0
# 2       1    CSE   NaN        NaN      NaN          1.0             5.0
# 3       1    CSE  9.59        NaN     10.0          3.0             8.0
# 4       1    CSE   NaN        NaN      9.8          3.0             4.0
# ..    ...    ...   ...        ...      ...          ...             ...
# 140     3    ECE  8.60        NaN      NaN          NaN             NaN
# 141     3    ECE   NaN        NaN      NaN          NaN             NaN
# 142     3    ECE   NaN        NaN      NaN          NaN             NaN
# 143     3    NaN   NaN        NaN      NaN          NaN             NaN
# 144     3    NaN   NaN        NaN      NaN          NaN             NaN
#
#      is_participate_hackathon  is_participated_extracurricular  \
# ...

# %%
df.isnull().sum()
# Out:
# tier                                 0
# branch                               2
# cgpa                                13
# inter_gpa                           61
# ssc_gpa                             60
# internships                          5
# no_of_projects                       5
# is_participate_hackathon             5
# is_participated_extracurricular      5
# no_of_programming_languages          5
# dsa                                  5
# mobile_dev                           5
# web_dev                              5
# Machine Learning                     5
# cloud                                5
# other_skills                       123
# is_placed                            5
# salary_as_fresher                    5
# dtype: int64

# %%
df['cgpa'] = df['cgpa'].fillna(df['cgpa'].mean())
df['inter_gpa'] = df['inter_gpa'].fillna(df['inter_gpa'].mean())
df['ssc_gpa'] = df['ssc_gpa'].fillna(df['ssc_gpa'].mean())
df['internships'] = df['internships'].fillna(df['internships'].mean())
df['no_of_projects'] = df['no_of_projects'].fillna(df['no_of_projects'].mean())
df['is_participate_hackathon'] = df['is_participate_hackathon'].fillna(df['is_participate_hackathon'].mean())
df['is_participated_extracurricular'] = df['is_participated_extracurricular'].fillna(df['is_participated_extracurricular'].mean())
df['no_of_programming_languages'] = df['no_of_programming_languages'].fillna(df['no_of_programming_languages'].mean())
df['dsa'] = df['dsa'].fillna(df['dsa'].mean())
df['mobile_dev'] = df['mobile_dev'].fillna(df['mobile_dev'].mean())
df['web_dev'] = df['web_dev'].fillna(df['web_dev'].mean())
df['Machine Learning'] = df['Machine Learning'].fillna(df['Machine Learning'].mean())
df['cloud'] = df['cloud'].fillna(df['cloud'].mean())
df['is_placed'] = df['is_placed'].fillna(df['is_placed'].mean())
df['salary_as_fresher'] = df['salary_as_fresher'].fillna(df['salary_as_fresher'].mean())

# Fill missing values in 'branch' with the mode
df['branch'] = df['branch'].fillna(df['branch'].mode()[0])


df.isnull().sum()
# Out:
# s_id                                10
# name                               145
# profile_link                        11
# tier                                 0
# gender                               8
# branch                               0
# cgpa                                 0
# inter_gpa                            0
# ssc_gpa                              0
# internships                          0
# no_of_projects                       0
# is_participate_hackathon             0
# is_participated_extracurricular      0
# no_of_programming_languages          0
# dsa                                  0
# mobile_dev                           0
# web_dev                              0
# Machine Learning                     0
# cloud                                0
# is_placed                            0
# salary_as_fresher                    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# s_id                                10
# name                               145
# profile_link                        11
# tier                                 0
# gender                               8
# branch                               0
# cgpa                                 0
# inter_gpa                            0
# ssc_gpa                              0
# internships                          0
# no_of_projects                       0
# is_participate_hackathon             0
# is_participated_extracurricular      0
# no_of_programming_languages          0
# dsa                                  0
# mobile_dev                           0
# web_dev                              0
# Machine Learning                     0
# cloud                                0
# is_placed                            0
# salary_as_fresher                    0
# dtype: int64

# %%
sea.boxplot(x=df['salary_as_fresher'], data=df)
plt.title('Box Plot of Column Name')
plt.show()

# %%
# Create a violin plot to visualize outliers
sea.violinplot(x=df['salary_as_fresher'], data=df)
plt.title('Violin Plot of Column Name')
plt.show()

# %%
plt.boxplot(df['salary_as_fresher'])
fig = plt.figure(figsize =(10, 7))
plt.show()

# %%
df.columns
# Out:
# Index(['tier', 'branch', 'cgpa', 'inter_gpa', 'ssc_gpa', 'internships',
#        'no_of_projects', 'is_participate_hackathon',
#        'is_participated_extracurricular', 'no_of_programming_languages', 'dsa',
#        'mobile_dev', 'web_dev', 'Machine Learning', 'cloud', 'is_placed',
#        'salary_as_fresher'],
#       dtype='object')

# %% [markdown]
# Now lets see this in heat maps

# %%
fig = plt.figure(figsize =(15, 7))
sea.heatmap(df.drop(columns=['branch']).corr(),annot=True)
# Out:
# <Axes: >

# %%
df.branch.unique()
# Out:
# array(['CSE', 'ECE', 'MECH', 'EEE'], dtype=object)

# %%
dummy = pd.get_dummies(df.branch)

# %%
df=pd.concat([df,dummy],axis=1)

# %%
df.shape
# Out:
# (145, 21)

# %%
# most frequent values filling here
# df['other_skills'].fillna(df['other_skills'].mode()[0], inplace=True)

# %%
# df.other_skills.isnull().sum()

# %%
df.drop(columns=['EEE','branch','ssc_gpa','inter_gpa'],inplace=True)

# %%
df.isnull().sum()
# Out:
# tier                               0
# cgpa                               0
# internships                        0
# no_of_projects                     0
# is_participate_hackathon           0
# is_participated_extracurricular    0
# no_of_programming_languages        0
# dsa                                0
# mobile_dev                         0
# web_dev                            0
# Machine Learning                   0
# cloud                              0
# is_placed                          0
# salary_as_fresher                  0
# CSE                                0
# ECE                                0
# MECH                               0
# dtype: int64

# %%
#dummy2=pd.get_dummies(df['other_skills'])
#df['other_skills'].value_counts()
#df.other_skills.unique()
#df=pd.concat([df,dummy2],axis=1)
#df.drop(columns=['other_skills','verilog,vlsi cad,matlab'
#],inplace=True)

# %%
X = df.drop(columns=['salary_as_fresher','is_placed'],axis=1)
y=df['salary_as_fresher']

# %%
X
# Out:
#      tier      cgpa  internships  no_of_projects  is_participate_hackathon  \
# 0       1  8.165758     2.000000        5.000000                  1.000000
# 1       1  8.165758     1.000000        4.000000                  1.000000
# 2       1  8.165758     1.000000        5.000000                  1.000000
# 3       1  9.590000     3.000000        8.000000                  1.000000
# 4       1  8.165758     3.000000        4.000000                  1.000000
# ..    ...       ...          ...             ...                       ...
# 140     3  8.600000     1.128571        2.628571                  0.507143
# 141     3  8.165758     1.128571        2.628571                  0.507143
# 142     3  8.165758     1.128571        2.628571                  0.507143
# 143     3  8.165758     1.128571        2.628571                  0.507143
# 144     3  8.165758     1.128571        2.628571                  0.507143
#
# ...

# %%
y.shape
# Out:
# (145,)

# %% [markdown]
# ## Train-Test Split (Data Splitting for Model Evaluation)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Create a dictionary containing different regression models
models = {
    'LinearRegression': LinearRegression(),
    'RandomForestRegressor': RandomForestRegressor(),
    'DecisionTreeRegressor': DecisionTreeRegressor()
}

# Loop through each model in the dictionary
for model_name, model in models.items():
    # Train the model on the training data
    model.fit(X_train, y_train)

    # Predict on training and testing sets
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Calculate performance metrics for training set
    model_train_mse = mean_squared_error(y_train, y_train_pred)
    model_train_r2 = r2_score(y_train, y_train_pred)

    # Calculate performance metrics for testing set
    model_test_mse = mean_squared_error(y_test, y_test_pred)
    model_test_r2 = r2_score(y_test, y_test_pred)

    # Print model performance metrics
    print('\n')
    print(model_name)
    print("=" * 25)

    # Print performance metrics for training set
    print("Performance of the model on training set:")
    print('-', "Mean Squared Error =", model_train_mse)
    print('-', "R-squared =", model_train_r2)

    print('\n')
    # Print performance metrics for testing set
    print("Performance of the model on testing set:")
    print('-', "Mean Squared Error =", model_test_mse)
    print('-', "R-squared =", model_test_r2)

    print("=" * 40)
# Out:
# LinearRegression
# ...
# Performance of the model on training set:
# - Mean Squared Error = 24.61153724410414
# - R-squared = 0.7215470854889023
#
#
# Performance of the model on testing set:
# - Mean Squared Error = 29.504417574046062
# - R-squared = 0.47755876116376417
# ...
#
#
# RandomForestRegressor
# ...
# Performance of the model on training set:
# - Mean Squared Error = 3.725642496923077
# - R-squared = 0.9578483862505113
#
#
# Performance of the model on testing set:
# - Mean Squared Error = 37.27782906933333
# - R-squared = 0.339913246847489
# ...
#
#
# DecisionTreeRegressor
# ...
# Performance of the model on training set:
# - Mean Squared Error = 0.008653846153846154
# - R-squared = 0.9999020910941332
#
#
# Performance of the model on testing set:
# - Mean Squared Error = 73.43599999999999
# - R-squared = -0.300347472336717
# ...

# %% [markdown]
# ## Model Initialization (Random Forest Regressor)**bold text**
#
# RandomForestRegressor() creates a model that uses many decision trees to make better predictions.

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

# %% [markdown]
# ## **Training the Model**
#
# model.fit(X_train, y_train) teaches the model to learn patterns from the training data so it can make predictions.

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## **Checking Model Accuracy**
#
# model.score(X_train, y_train) shows how well the model fits the training data (higher score = better fit).

# %%
model.score(X_train,y_train)
# Out:
# 0.9539615279682049

# %% [markdown]
# # **Making Predictions**
#
# pre_salary = model.predict(X_test) uses the trained model to predict outcomes for the test data.

# %%
pre_salary=model.predict(X_test)

# %%
pre_salary
# Out:
# array([15.6423, 18.63  , 27.212 , 12.6013, 13.9033,  5.055 , 18.652 ,
#        13.2923, 10.9023, 10.1283, 30.535 , 18.9966, 12.0269, 26.89  ,
#         4.47  ])

# %%
X_test
# Out:
#      tier  cgpa  internships  no_of_projects  is_participate_hackathon  \
# 25      2  9.63     4.000000        2.000000                  0.000000
# 6       1  8.10     0.000000        6.000000                  0.000000
# 3       1  9.59     3.000000        8.000000                  1.000000
# 45      2  8.13     1.000000        4.000000                  1.000000
# 40      2  8.31     2.000000        2.000000                  1.000000
# 67      3  8.66     1.000000        1.000000                  0.000000
# 38      2  9.38     3.000000        3.000000                  1.000000
# 15      2  9.17     3.000000        4.000000                  1.000000
# 136     3  9.50     2.000000        3.000000                  1.000000
# 140     3  8.60     1.128571        2.628571                  0.507143
# 84      1  9.50     1.000000        5.000000                  1.000000
# 42      2  9.06     3.000000        3.000000                  1.000000
# ...

# %% [markdown]
# ## **Importing Evaluation Metrics**
#
# We import mean_absolute_error and mean_absolute_percentage_error to measure how accurate the model’s predictions are.

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error

# %% [markdown]
# # **Calculating MAE (Mean Absolute Error)**
#
# mean_absolute_error(y_test, pre_salary) measures the average difference between actual and predicted values. Lower value = better predictions.

# %%
mean_absolute_error(y_test,pre_salary)
# Out:
# 4.511633333333332

# %% [markdown]
# # **Calculating MAPE (Mean Absolute Percentage Error)**
#
# mean_absolute_percentage_error(y_test, pre_salary) shows the average prediction error as a percentage. Lower value = better predictions.

# %%
mean_absolute_percentage_error(y_test,pre_salary)
# Out:
# 2859785763380264.5

# %% [markdown]
# # **Using Decision Tree & Random Forest Models**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
RR_M=RandomForestRegressor()
RR_M.fit(X_train,y_train)
DT.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## **Random Forest Training Score**
#
# RR_M.score(X_train, y_train) shows how well the Random Forest model fits the training data. Higher score = better fit.

# %%
RR_M.score(X_train,y_train)
# Out:
# 0.9527197962588694

# %% [markdown]
# ## **Random Forest Predictions & MAE**
#
# Out1 = RR_M.predict(X_test) → Predicts outcomes using the Random Forest model.
#
# mean_absolute_error(Out1, y_test) → Measures the average difference between actual and predicted values. Lower = better.

# %%
Out1=RR_M.predict(X_test)
mean_absolute_error(Out1,y_test)
# Out:
# 4.344666666666666

# %% [markdown]
# ## **Decision Tree Training Score**
#
#  DT.score(X_train, y_train) shows how well the Decision Tree model fits the training data. Higher score = better fit.

# %%
DT.score(X_train,y_train)
# Out:
# 0.9999020910941332

# %% [markdown]
# ## **Decision Tree Predictions**
#
# out = DT.predict(X_test) uses the trained Decision Tree model to predict outcomes for the test data.

# %%
out=DT.predict(X_test)
out
# Out:
# array([12.  , 18.  , 30.  ,  7.7 , 13.  ,  7.  , 25.  , 17.  , 13.  ,
#        10.23, 30.  , 23.  , 12.  , 30.  ,  4.5 ])

# %% [markdown]
# ## **Decision Tree MAE**
#
#  mean_absolute_error(out, y_test) measures the average difference between actual and predicted values for the Decision Tree model. Lower value = better predictions.

# %%
mean_absolute_error(out,y_test)
# Out:
# 6.253333333333333

# %% [markdown]
# ## **Viewing Test Features**
#
# X_test.columns shows all the column names (features) in the test dataset that the model uses for predictions.

# %%
X_test.columns
# Out:
# Index(['tier', 'cgpa', 'internships', 'no_of_projects',
#        'is_participate_hackathon', 'is_participated_extracurricular',
#        'no_of_programming_languages', 'dsa', 'mobile_dev', 'web_dev',
#        'Machine Learning', 'cloud', 'CSE', 'ECE', 'MECH'],
#       dtype='object')

# %% [markdown]
# # **Saves the trained Decision Tree model to a file so you can reuse it later without retraining**

# %%
import pickle

pickle.dump(DT,open('salary_model.pkl', 'wb'))

# %% [markdown]
# ## **Installing IBM Watson ML Library**
#
# !pip install -U ibm-watson-machine-learning installs the IBM Watson Machine Learning library, which is used to deploy and manage ML models on IBM Cloud.

# %%
# !pip install -U ibm-watson-machine-learning
